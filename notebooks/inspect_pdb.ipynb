# %%
# import openmm as mm
import openmm.app as app 
from boltzkit.utils.plot_molecule import plot_matplotlib_molecule

# %%
pdb_file_path = "data/alanine-dipeptide-implicit.pdb"
molecule = app.PDBFile(pdb_file_path)

# %%
print("topology:", molecule.topology) # molecular graph (without positions)
print("positions:", molecule.positions) # atom positions
print("unit:", molecule.positions.unit)
# Out:
# topology: <Topology; 1 chains, 3 residues, 22 atoms, 21 bonds>
# ...

# %%
plot_matplotlib_molecule(molecule.topology, molecule.positions)
# Out:
# convert to nanometers
